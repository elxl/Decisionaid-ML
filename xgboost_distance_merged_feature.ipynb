# %%
# %load_ext autoreload
# %autoreload 2
import xgboost as xgb
import pandas as pd
import numpy as np
from utils import k_fold_cross_validation_regression
# Out:
# /Users/pinyen/opt/anaconda3/envs/da-ml/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index

# %%
df_train = pd.read_csv('data/data_processed_train_merged.csv')
df_test = pd.read_csv('data/data_processed_test_merged.csv')
df = pd.concat((df_train, df_test), ignore_index=True)

string_cols = ['survey_language', 'disability']
df[string_cols] = df[string_cols].astype('category')
df[string_cols] = df[string_cols].apply(lambda x: x.cat.codes)

# %%
df
# Out:
#           id  person_id  trip_n travel_date  travel_date_dow  \
# 0          0          0       0  30/05/2019                4
# 1          1          0       1  01/06/2019                6
# 2          2          0       2  02/06/2019                7
# 3          3          0       3  02/06/2019                7
# 4          4          0       4  03/06/2019                1
# ...      ...        ...     ...         ...              ...
# 65733  65787       2991      48  27/06/2019                4
# 65734  65788       2991      49  27/06/2019                4
# 65735  65789       2991      50  27/06/2019                4
# 65736  65790       2991      51  27/06/2019                4
# 65737  65791       2991      52  27/06/2019                4
#
#        o_purpose_category  d_purpose_category  num_non_hh_travelers  \
# 0                       7                   2                     0
# 1                       6                   1                     0
# 2                       7                   7                     1
# 3                       7                   7                     1
# 4                       7                   7                     0
# ...                   ...                 ...                   ...
# 65733                   8                   8                     2
# 65734                   8                   8                     2
# 65735                   8                   8                     2
# 65736                   8                   8                     2
# 65737                   8                   8                     0
#
#        num_hh_travelers  num_travelers  ...  num_students  disability  \
# 0                     1              1  ...             2           3
# 1                     1              1  ...             2           3
# 2                     2              3  ...             2           3
# 3                     2              3  ...             2           3
# 4                     1              1  ...             2           3
# ...                 ...            ...  ...           ...         ...
# 65733                 2              4  ...             0           4
# 65734                 2              4  ...             0           4
# 65735                 2              4  ...             0           4
# 65736                 2              4  ...             0           4
# 65737                 2              2  ...             0           4
#
#        trip_distance    mode  trip_distance_category  age_merged  \
# 0               13.4  subway                    long           1
# 1                3.7   drive                    long           1
# 2                9.8   drive                    long           1
# 3               11.1   drive                    long           1
# 4                2.5   drive                  medium           1
# ...              ...     ...                     ...         ...
# 65733            NaN     NaN                     NaN           1
# 65734            NaN     NaN                     NaN           1
# 65735            NaN     NaN                     NaN           1
# 65736            NaN     NaN                     NaN           1
# 65737            NaN     NaN                     NaN           1
#
#        income_aggregate_merged  res_type_merged  education_merged  \
# 0                            1                0                 1
# 1                            1                0                 1
# 2                            1                0                 1
# 3                            1                0                 1
# 4                            1                0                 1
# ...                        ...              ...               ...
# 65733                        0                2                 0
# 65734                        0                2                 0
# 65735                        0                2                 0
# 65736                        0                2                 0
# 65737                        0                2                 0
#
#        travel_date_dow_merged
# 0                           0
# 1                           1
# 2                           1
# 3                           1
# 4                           0
# ...                       ...
# 65733                       0
# 65734                       0
# 65735                       0
# 65736                       0
# 65737                       0
#
# [65738 rows x 42 columns]

# %%
candidate_cols = [
#      'travel_date_dow',
     'o_purpose_category',
     'd_purpose_category',
#      'num_non_hh_travelers',
#      'num_hh_travelers',
     'num_travelers',
#      'o_location_type',
#      'd_location_type',
#      'o_congestion',
     'd_congestion',
#      'age',
#      'employment',
#      'student',
     'license',
#      'planning_apps',
#      'industry',
#      'gender',
#      'education',
#      'survey_language',
#      'num_bicycles',
     'num_vehicles',
#      'res_type',
     'rent_own',
#      'income_aggregate',
#      'num_people',
#      'num_adults',
#      'num_kids',
#      'num_workers',
#      'num_students',
#      'disability'
#     'trip_distance'
    'res_type_merged',
    'income_aggregate_merged',
    'age_merged',
    'travel_date_dow_merged',
    'education_merged'
]


categorial_columns = ['travel_date_dow', 'o_purpose_category', 'd_purpose_category', 'o_location_type',
                      'd_location_type', 'age', 'employment', 'license', 'planning_apps', 'industry',
                      'gender', 'survey_language', 'res_type', 'rent_own',  'disability']

onehot = pd.get_dummies(df[candidate_cols], columns=[x for x in categorial_columns if x in candidate_cols])

X_train_val = onehot.to_numpy()[:len(df_train)]
group_train_val = df['person_id'].to_numpy()[:len(df_train)]
y_train_val = df['trip_distance'][:len(df_train)]

X_test = onehot.to_numpy()[len(df_train):]

# %%
model = xgb.XGBRegressor(objective='reg:squarederror', # objective_mape or 'reg:squarederror'
                          n_estimators = 100,
                        learning_rate=0.0399,
                          n_jobs=-1,
                          random_state=42,
                          use_label_encoder =False)

train_metrics, val_metrics = k_fold_cross_validation_regression(X_train_val, y_train_val, group_train_val, model)

# %%
metrics = np.concatenate((train_metrics, val_metrics), axis=1)
metrics = metrics[:,[0, 3, 1, 4, 2, 5]]
train_metrics_df = pd.DataFrame(metrics, columns=['mse-train', 'mse-val', 'mae-train', 'mae-val', 'mape-train', 'mape-val'])
train_metrics_df
# Out:
#    mse-train    mse-val  mae-train   mae-val  mape-train  mape-val
# 0  10.746667  12.735779   2.252602  2.436867    4.010137  3.990835
# 1  11.205772  10.844584   2.303178  2.354970    4.017079  4.616398
# 2  10.924373  12.223426   2.274632  2.383062    4.002506  4.201645
# 3  11.020429  11.714108   2.279193  2.320139    3.993308  3.915668
# 4  11.112542  11.292910   2.303119  2.363204    4.080246  4.353480

# %%
train_metrics_df.to_csv('stats/xgboost_distance_merged.csv')

# %% [markdown]
# ## Hyperparameter search

# %%
from scipy.stats import loguniform
from sklearn.model_selection import RandomizedSearchCV

distributions = {
    'learning_rate': loguniform(10**-5, 1),
#     'max_depth': [2, 4, 6, 8]
}

k_fold = GroupKFold(n_splits=5)
search = RandomizedSearchCV(model,
                            distributions,
                            random_state=1,
                            n_jobs=4,
                            scoring='neg_mean_squared_error', # 'neg_mean_squared_error' or 'neg_mean_absolute_percentage_error'
                            n_iter=10,
                            cv=k_fold
                           ).fit(X_train_val, y_train_val, groups=group_train_val)
print('best parameter', search.best_params_)
print('best score', search.best_score_)
# Out:
# /Users/pinyen/opt/anaconda3/envs/da-ml/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/pinyen/opt/anaconda3/envs/da-ml/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/pinyen/opt/anaconda3/envs/da-ml/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# /Users/pinyen/opt/anaconda3/envs/da-ml/lib/python3.10/site-packages/xgboost/compat.py:36: FutureWarning: pandas.Int64Index is deprecated and will be removed from pandas in a future version. Use pandas.Index with the appropriate dtype instead.
#   from pandas import MultiIndex, Int64Index
# best parameter {'learning_rate': 0.03995972283135063}
# best score -11.763981254227025

# %%
search.cv_results_
# Out:
# {'mean_fit_time': array([8.27785816, 8.23126364, 8.37262926, 8.51516647, 8.5367651 ,
#         8.45705004, 8.48336239, 8.44908638, 8.72131   , 6.90284576]),
#  'std_fit_time': array([0.11416734, 0.06374142, 0.08875688, 0.08827849, 0.12907577,
#         0.03112605, 0.08870074, 0.0900788 , 0.22575376, 1.91892205]),
#  'mean_score_time': array([0.00979939, 0.01095715, 0.01103878, 0.00961866, 0.01123719,
#         0.01163635, 0.01050868, 0.01041384, 0.01392894, 0.01602602]),
#  'std_score_time': array([0.00106593, 0.00186699, 0.00105579, 0.00128033, 0.00209003,
#         0.00120802, 0.0027242 , 0.00111447, 0.00219296, 0.00908326]),
#  'param_learning_rate': masked_array(data=[0.001216494146415184, 0.03995972283135063,
#                     1.0013176560941263e-05, 0.00032483503450866794,
#                     5.4172571827679706e-05, 2.8952960233492824e-05,
#                     8.536916958038756e-05, 0.000534322712559412,
#                     0.0009634681692624377, 0.004944059287398676],
#               mask=[False, False, False, False, False, False, False, False,
#                     False, False],
#         fill_value='?',
#              dtype=object),
#  'params': [{'learning_rate': 0.001216494146415184},
#   {'learning_rate': 0.03995972283135063},
#   {'learning_rate': 1.0013176560941263e-05},
#   {'learning_rate': 0.00032483503450866794},
#   {'learning_rate': 5.4172571827679706e-05},
#   {'learning_rate': 2.8952960233492824e-05},
#   {'learning_rate': 8.536916958038756e-05},
#   {'learning_rate': 0.000534322712559412},
#   {'learning_rate': 0.0009634681692624377},
#   {'learning_rate': 0.004944059287398676}],
#  'split0_test_score': array([-18.24004444, -12.73306638, -19.50925897, -19.15051622,
#         -19.45768075, -19.48708747, -19.42149589, -18.92314475,
#         -18.48349764, -15.6940987 ]),
#  'split1_test_score': array([-14.66806932, -10.85161893, -15.77517415, -15.4596197 ,
#         -15.72968071, -15.75561023, -15.69779423, -15.26062138,
#         -14.87848793, -12.57179509]),
#  'split2_test_score': array([-16.7413925 , -12.23456944, -17.90215534, -17.57222239,
#         -17.85461878, -17.88171694, -17.82128634, -17.36389062,
#         -16.96289238, -14.46794047]),
#  'split3_test_score': array([-16.61606634, -11.71340128, -17.83047637, -17.48493665,
#         -17.78072332, -17.80908492, -17.74583274, -17.26641252,
#         -16.84661773, -14.21992556]),
#  'split4_test_score': array([-15.00499606, -11.28725025, -16.14137204, -15.81642889,
#         -16.09450148, -16.12122784, -16.06162468, -15.61156158,
#         -15.21964809, -12.88089964]),
#  'mean_test_score': array([-16.25411373, -11.76398125, -17.43168737, -17.09674477,
#         -17.38344101, -17.41094548, -17.34960678, -16.88512617,
#         -16.47822875, -13.96693189]),
#  'std_test_score': array([1.29523765, 0.66675558, 1.34949074, 1.33522555, 1.34748658,
#         1.34862988, 1.34607457, 1.32582782, 1.3065151 , 1.1334896 ]),
#  'rank_test_score': array([ 3,  1, 10,  6,  8,  9,  7,  5,  4,  2], dtype=int32)}

# %% [markdown]
# ## train model on whole dataset

# %%
## model parameter from search results
model = xgb.XGBRegressor(objective='reg:squarederror', # reg:squarederror
                         n_estimators = 100,
                         learning_rate=0.0399, 
                         max_depth=4,
                         n_jobs=-1,
                         random_state=42,
                         use_label_encoder =False)

model.fit(X_train_val, y_train_val)

# calculate training metrics
y_train_val_pred = model.predict(X_train_val)
print(mse_mae_mape(y_train_val, y_train_val_pred))
# Out:
# (11.611507715799027, 2.359322291421922, 4.2318729685255745)

# %%
pd.DataFrame(y_train_val_pred).hist(bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %%
pd.DataFrame(y_train_val).hist(bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'trip_distance'}>]], dtype=object)

# %% [markdown]
# ## Read test data

# %%
y_train_val_pred = model.predict(X_train_val)
y_test_pred = model.predict(X_test)

# %%
pd.DataFrame(y_test_pred).hist(bins=50)
# Out:
# array([[<AxesSubplot:title={'center':'0'}>]], dtype=object)

# %%
# Append prediction to dataset
df_train['trip_distance'] = y_train_val_pred
df_test['trip_distance'] = y_test_pred

# %%
# Out:
#        Unnamed: 0     id  person_id  trip_n travel_date  travel_date_dow  \
# 0               0  39498       1795       0  07/06/2019                5
# 1               1  39499       1795       1  07/06/2019                5
# 2               2  39500       1795       2  07/06/2019                5
# 3               3  39501       1796       0  05/06/2019                3
# 4               4  39502       1796       1  05/06/2019                3
# ...           ...    ...        ...     ...         ...              ...
# 26289       26289  65787       2991      48  27/06/2019                4
# 26290       26290  65788       2991      49  27/06/2019                4
# 26291       26291  65789       2991      50  27/06/2019                4
# 26292       26292  65790       2991      51  27/06/2019                4
# 26293       26293  65791       2991      52  27/06/2019                4
#
#        o_purpose_category  d_purpose_category  num_non_hh_travelers  \
# 0                       1                   6                     0
# 1                       6                   6                     0
# 2                       6                   1                     0
# 3                       1                   6                     0
# 4                       6                   7                     0
# ...                   ...                 ...                   ...
# 26289                   8                   8                     2
# 26290                   8                   8                     2
# 26291                   8                   8                     2
# 26292                   8                   8                     2
# 26293                   8                   8                     0
#
#        num_hh_travelers  ...  res_type  rent_own  income_aggregate  \
# 0                     1  ...         6         2                 1
# 1                     1  ...         6         2                 1
# 2                     1  ...         6         2                 1
# 3                     1  ...         5         2                 1
# 4                     1  ...         5         2                 1
# ...                 ...  ...       ...       ...               ...
# 26289                 2  ...         5         2                 2
# 26290                 2  ...         5         2                 2
# 26291                 2  ...         5         2                 2
# 26292                 2  ...         5         2                 2
# 26293                 2  ...         5         2                 2
#
#        num_people  num_adults  num_kids  num_workers  num_students  \
# 0               2           2         0            1             1
# 1               2           2         0            1             1
# 2               2           2         0            1             1
# 3               2           1         1            0             2
# 4               2           1         1            0             2
# ...           ...         ...       ...          ...           ...
# 26289           2           2         0            2             0
# 26290           2           2         0            2             0
# 26291           2           2         0            2             0
# 26292           2           2         0            2             0
# 26293           2           2         0            2             0
#
#        disability  trip_distance
# 0            none       1.060259
# 1            none       1.060259
# 2            none       1.635832
# 3            none       1.205747
# 4            none       1.039199
# ...           ...            ...
# 26289        none       0.345874
# 26290        none       0.345874
# 26291        none       0.345874
# 26292        none       0.345874
# 26293        none       0.718473
#
# [26294 rows x 36 columns]

# %%
# save test data with trip_distance predictions to file
df_train.to_csv('data/xgboost_distance_regression_merged_train', index=False)
df_test.to_csv('data/xgboost_distance_regression_merged_test', index=False)
